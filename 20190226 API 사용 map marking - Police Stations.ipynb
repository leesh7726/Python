# %%
#!pip install googlemaps # install 
#!pip install folium # 지도 그리는 모듈
#!pip install tqdm  # 바 형태로 진행상황 표시

# %%
from tqdm import tqdm_notebook

import  folium # map 그려주는 모듈
fm = folium.Map([37.5,127]) 

folium.Marker([37.5636465, 126.9895796], popup="중부경찰서", icon=folium.Icon(icon='cloud', icon_color= 'blue')).add_to(fm) #마커 찍기
fm

# %%
import pandas as pd
import numpy as np
import googlemaps

gmaps_key = "AIzaSyDnj2IQmVLNvZj8IhvDFc2Ym5o7m9uLZa8"
gmaps = googlemaps.Client(key = gmaps_key)

# %%
crime_seoul = pd.read_csv("crime_Seoul2.csv", encoding='utf-8', index_col=0)
crime_seoul['관서명']
stations = []
for name in crime_seoul['관서명'] :
    stations.append('서울' + name[:-1] + '경찰서') # 서울OO경찰서로 바꿔주려고
    
import  folium # map 그려주는 모듈
fm = folium.Map(location=[37.5,127], zoom_start=10) 

for station in stations:
    tmp = gmaps.geocode(station, language='ko')
    folium.Marker([tmp[0]['geometry']['location']['lat'], tmp[0]['geometry']['location']['lng']], popup=station, icon=folium.Icon(icon='cloud')).add_to(fm) #마커 찍기


fm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## 처음 짠거 위에껀 수정본

#gmaps.geocode('서울중부경찰서', language='ko')
crime_seoul = pd.read_csv("crime_Seoul2.csv", encoding='utf-8', index_col=0)
crime_seoul['관서명']
stations = []
for name in crime_seoul['관서명'] :
    stations.append('서울' + name[:-1] + '경찰서') # 서울OO경찰서로 바꿔주려고
    
    ######
    
for station in stations :
    gmaps.geocode(station, language='ko')

    
# tmp = gmaps.geocode('서울광진경찰서', language='ko') # 1개짜리 List 형식으로 들어가있다 -> 추출할때 [0] 인덱스로 접근
# tmp[0].get("formatted_address")
# tmp2 = tmp[0].get("geometry")
# lat = tmp2['location']['lat']
# lng = tmp2['location']['lng']



dic = {}
import  folium # map 그려주는 모듈
fm = folium.Map([37.5,127]) 

for station in stations:
    tmp = gmaps.geocode(station, language='ko')
    tmp[0].get("formatted_address")
    tmp2 = tmp[0].get("geometry")
    
    
    dic[station] = {}
    dic[station]['lat'] = []
    dic[station]['lng'] = []
    dic[station]['lat'] = tmp2['location']['lat']
    dic[station]['lng'] = tmp2['location']['lng']
    folium.Marker([dic[station]['lat'], dic[station]['lng']], popup=station, icon=folium.Icon(icon='cloud')).add_to(fm) #마커 찍기
    
    
    
fm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
