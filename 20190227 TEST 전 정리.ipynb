# %%
            <<<<<<< DB, SQL >>>>>>>

>> 데이터 베이스란?
 - 특정 조직의 여러 사용자가 공유하여 사용할 수 있도록 통합해서 지정한 운영 데이터 집합

>> 데이터베이스 기능?
 - 정의기능
 - 조작기능
 - 제어기능

>> T-SQL에서 제공되는 JOIN 종류
 - FULL JOIN
 - INNER JOIN
 - OUTER JOIN(LEFT, RIGHT)
 
>> SELF JOIN -> 자기 자신을 JOIN

>> DBMS의 특징 -> PPT 확인

>> 데이터베이스를 정의하는 단계
 - 개념 단계
 - 내부 단계
 - 외부 단계

>> 데이터베이스 모델링
 - 현실 세계의 업무적인 프로세스를 물리적으로 데이터베이스화 시키기 위한 과정

>> 데이터베이스 특성
 - 실시간 접근
 - 동시 공유
 - 계속 변화

>> 데이터베이스 모델링
 - 개념적 -> 엔터티(Entity), 속성(Attribute), 식별자(Identifier), 차수(Relation) -> ???관계???
 - 논리적 -> 테이블(Table), 컬럼(Column), 주키(Primary Key), 참조키(Reference Key)
 - 물리적
    
>> 데이터 모델링
 - 데이터의 중복성을 제기하고 속성들을 본래의 제자리에 위치시키고자 하는 것

>> 데이터베이스 정의어,조작어,제어어
 - 정의어(DDL) -> CREATE, VIEW
 - 조작어(DML) -> SELECT, INSERT, UPDATE, DELETE

>> 형변환 -> CONVERT, CAST
    
>> 중복제거 -> DISTINCT

# %%
            <<<<<<< PYTHON >>>>>>>

>> 파이썬 특징
 - 스크립트 언어
 - 인터프리터 방식
 - C 라이브러리 형태 & C와 궁합이 잘맞음
 
>> INDEX & SLICING
 - s = 'my home'
    -> s[0] = 'm'
    -> s[-1] = 'e'
    -> s[0:1] = 'm'
    -> s[-1:] = 'e'
    
>> Python에서의 특징 중 관련 없는 것
 -시스템과 밀접한 영역의 코딩 할 수 없음.

>> Pandas
 - Series (1차원)
 - DataFrame (2차원)
 - Panel (3차원)
    
>> numpy
 - ndarray

>> 파이썬자료형
 - List []
 - Tuple ()
 - Dictionary {}

>> Pandas 병합 -> merge

>> 자료형별 연산
    "test" * 2
    # Output = 'testtest'
    
    2*2
    # Output = 4

    [1,2] + [3,4]
    # Output = [1, 2, 3, 4]

>> Beautiful Soup -> 웹사이트 데이터 수집을 위한 모듈

>> Numeric Python -> Numpy

# %%
            <<<<<<< 실습 >>>>>>>
>> 계산기 만들기
>> 서울 기온데이터를 읽어서 가장 낮은 온도 데이터의 연도 출력

# %%
            <<<<<<< DB, SQL >>>>>>>

>> 데이터 베이스란?
 - 특정 조직의 여러 사용자가 공유하여 사용할 수 있도록 통합해서 지정한 운영 데이터 집합

>> 데이터베이스 기능?
 - 정의기능
 - 조작기능
 - 제어기능

>> T-SQL에서 제공되는 JOIN 종류
 - FULL JOIN
 - INNER JOIN
 - OUTER JOIN(LEFT, RIGHT)
 
>> SELF JOIN -> 자기 자신을 JOIN

>> DBMS의 특징 -> PPT 확인

>> 데이터베이스를 정의하는 단계
 - 개념 단계
 - 내부 단계
 - 외부 단계

>> 데이터베이스 모델링
 - 현실 세계의 업무적인 프로세스를 물리적으로 데이터베이스화 시키기 위한 과정

>> 데이터베이스 특성
 - 실시간 접근
 - 동시 공유
 - 계속 변화

>> 데이터베이스 모델링
 - 개념적 -> 엔터티(Entity), 속성(Attribute), 식별자(Identifier), 차수(Relation) -> ???관계???
 - 논리적 -> 테이블(Table), 컬럼(Column), 주키(Primary Key), 참조키(Reference Key)
 - 물리적
    
>> 데이터 모델링
 - 데이터의 중복성을 제기하고 속성들을 본래의 제자리에 위치시키고자 하는 것

>> 데이터베이스 정의어,조작어,제어어
 - 정의어(DDL) -> CREATE, VIEW
 - 조작어(DML) -> SELECT, INSERT, UPDATE, DELETE

>> 형변환 -> CONVERT, CAST
    
>> 중복제거 -> DISTINCT



            <<<<<<< PYTHON >>>>>>>

>> 파이썬 특징
 - 스크립트 언어
 - 인터프리터 방식
 - C 라이브러리 형태 & C와 궁합이 잘맞음
 
>> INDEX & SLICING
 - s = 'my home'
    -> s[0] = 'm'
    -> s[-1] = 'e'
    -> s[0:1] = 'm'
    -> s[-1:] = 'e'
    
>> Python에서의 특징 중 관련 없는 것
 -시스템과 밀접한 영역의 코딩 할 수 없음.

>> Pandas
 - Series (1차원)
 - DataFrame (2차원)
 - Panel (3차원)
    
>> numpy
 - ndarray

>> 파이썬자료형
 - List []
 - Tuple ()
 - Dictionary {}

>> Pandas 병합 -> merge

>> 자료형별 연산
    "test" * 2
    # Output = 'testtest'
    
    2*2
    # Output = 4

    [1,2] + [3,4]
    # Output = [1, 2, 3, 4]

>> Beautiful Soup -> 웹사이트 데이터 수집을 위한 모듈

>> Numeric Python -> Numpy



            <<<<<<< 실습 >>>>>>>
>> 계산기 만들기
>> 서울 기온데이터를 읽어서 가장 낮은 온도 데이터의 연도 출력
