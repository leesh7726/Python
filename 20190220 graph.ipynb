# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])

plt.title("Graph  #1")
plt.xlabel("X")
plt.ylabel("Y")


plt.show()

# %%
import csv
f = open("seoul.csv", encoding='UTF-8')
data = csv.reader(f)
next(data)

temperature = []
for row in data:
    if(row[-1] != "" and (row[0].split("-")[1] == "11" and row[0].split("-")[2] == "24" )):
        temperature.append(float(row[-1]))
        
print(temperature)


import matplotlib.pyplot as plt

plt.plot(temperature)
plt.title("temp 11/24")
plt.xlabel("index")
plt.ylabel("temperature")

plt.show()
# Out:
# [5.9, 7.8, 7.2, 11.0, 10.3, 9.3, 9.9, 7.5, 11.8, 16.5, 13.2, 1.0, 2.8, 8.7, 3.7, 4.9, 14.1, -1.1, 11.4, 9.8, 12.7, 13.8, 4.4, 2.0, 13.7, 11.3, 12.8, 13.7, 11.3, 8.4, 1.3, 5.4, 11.7, 9.4, 10.1, 10.1, 11.4, 20.8, 13.4, 16.5, 7.3, 12.1, 9.8, 17.0, 11.4, 1.5, 16.1, 9.7, 6.4, 10.2, 6.4, 1.0, 9.8, 6.9, 12.2, 12.2, 11.0, 18.1, 2.4, 6.7, 12.2, 0.1, 10.8, 8.0, 5.4, 2.4, 11.2, 14.6, 5.2, 10.3, 5.1, 3.8, 8.0, 9.3, 4.7, 11.7, 9.4, 1.0, 11.2, 11.8, 4.6, 13.6, 1.9, 11.0, 5.9, 8.4, 15.3, 5.5, 15.7, 13.0, 12.7, 8.8, 8.3, 14.3, 12.6, 12.6, 10.0, 12.6, 13.5, 10.7, 2.0, 6.7, 10.6, 13.2, 8.8, 2.4, 2.9]

# %%
import matplotlib.pyplot as plt
plt.hist([1,2,3,3,4,4,4,4])
plt.show()

# %%
import matplotlib.pyplot as plt
import random
dice = []
for i in range(100):
    dice.append(random.randint(1,6))

plt.hist(dice)
plt.show()
